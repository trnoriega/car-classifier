# %%
import os
import pickle

from cars_utils import plot_metrics

# %%
DATA_DIR = os.path.join(os.getcwd(), 'data', 'VGG16')
pkl_path = os.path.join(DATA_DIR, '1_VGG16_0_100.pkl')
with open(pkl_path, 'rb') as f:
    one_VGG16_metrics = pickle.load(f)

# %%
key_list = ['categorical_accuracy',
            'top_3_acc',
            'loss']
show = plot_metrics(one_VGG16_metrics, key_list)
