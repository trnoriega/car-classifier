# %% [markdown]
# # Validating a trained network
#
# In this notebook I will validate the model trained in
# [Inceptionv3_21](inception_v3_experiments/Inceptionv3_21.ipynb)

# %%
import os
import pickle

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

from custom.tools import pickle_variable_to_path

# %% [markdown]
# ### Body-type clustering

# %%
WORKING_DIR = os.getcwd()
OPEN_DIR = os.path.join(WORKING_DIR, 'data', 'notebooks', '5_model_validation')
DATA_DIR = os.path.join(WORKING_DIR, 'data', 'InceptionV3')
LOOKUP_PATH = os.path.join(DATA_DIR, 'I_15_lookup_dict.pkl')

with open(os.path.join(OPEN_DIR, 'label_category_dict_corrected.pkl'), 'rb') as f:
    label_category_dict = pickle.load(f)
    
with open(os.path.join(OPEN_DIR, 'test_y_true.pkl'), 'rb') as f:
    test_y_true = pickle.load(f)

with open(os.path.join(OPEN_DIR, 'test_y_pred.pkl'), 'rb') as f:
    test_y_pred = pickle.load(f)
    
with open(os.path.join(LOOKUP_PATH), 'rb') as f:
    lookup_dict = pickle.load(f)

# %%
def find_top_percent_prediction_indices(prediction_array_row, **kwargs):
    """
    prediction array row should be shape (classes,)
    """
    # sort them from greatest to lowest
    top_idxs = np.argsort(prediction_array_row)[::-1]
#     print(top_idxs)
    
    # only select ones that add up to 99% certainty
    selected = []
    certainty = 0
    i = 0
    while certainty <= kwargs['percent']/100:
#         print(top_idxs[i])
        selected.append(top_idxs[i])
        certainty += prediction_array_row[top_idxs[i]]
        i += 1
    return selected

# show that it worked
test_i = 1
print(test_y_pred[test_i, find_top_percent_prediction_indices(test_y_pred[test_i,:], percent=95)])
# Out:
# [ 0.42262146  0.31554991  0.16753168  0.06199163]

# %%
def find_top_k_prediction_indices(prediction_array_row, **kwargs):
    """
    prediction array row should be shape (classes,)
    """
    # find the indices of the top 5 predictions for each row
    top_idxs = np.argpartition(prediction_array_row, -(kwargs['k']+1))[-(kwargs['k']):]
    # sort them from greatest to lowest
    top_idxs = top_idxs[np.argsort(prediction_array_row[top_idxs])][::-1]
    return top_idxs

# show that it worked
print(test_y_pred[0, find_top_k_prediction_indices(test_y_pred[0,:], k=3)])
# Out:
# [  9.99222636e-01   7.47231010e-04   2.20297807e-05]

# %%
def make_pred_dict_list(y_true, y_pred, lookup_dict, label_category_dict, index_finder, **kwargs):
    prediction_dict_list = []
    for row in range(y_true.shape[0]):
        prediction_dict = {'pred_labels': [], 'pred_bodies': []}
        true_idx = np.argmax(y_true[row,:])
        true_label = lookup_dict[true_idx]
        prediction_dict['true_label'] = true_label
        prediction_dict['true_body'] = label_category_dict[true_label]['body_style']
        top_idxs = index_finder(y_pred[row,:], **kwargs)
        for i in top_idxs:
            pred_label = lookup_dict[i]
            pred_body = label_category_dict[pred_label]['body_style']
            prediction_dict['pred_labels'].append(pred_label)
            prediction_dict['pred_bodies'].append(pred_body)
        prediction_dict_list.append(prediction_dict)
    return prediction_dict_list

# %%
### Change a pred_dict_list to remove non-consensus body types
def keep_consensus_body(pred_dict_list):
    import collections
    import copy
    pred_dict_list_copy = copy.deepcopy(pred_dict_list)
    for pred_dict in pred_dict_list_copy:
        body_count = collections.Counter(pred_dict['pred_bodies'])
        most_common_body = body_count.most_common(2)
        most_common_body = [tup[0] for tup in most_common_body]
        pred_dict['consensus_body'] = most_common_body
        pred_dict['consensus_labels'] = []
        for i, label in enumerate(pred_dict['pred_labels']):
            if pred_dict['pred_bodies'][i] in most_common_body:
                pred_dict['consensus_labels'].append(label)
    return pred_dict_list_copy

# %%
top_5_pred_dict_list = make_pred_dict_list(
    test_y_true, test_y_pred,
    lookup_dict, label_category_dict,
    find_top_k_prediction_indices, k=5
)

consensus_top_5 = keep_consensus_body(top_5_pred_dict_list)

# %%
percent_pred_dict_list = make_pred_dict_list(
    test_y_true, test_y_pred,
    lookup_dict, label_category_dict,
    find_top_percent_prediction_indices, percent=99
)

consensus_percent = keep_consensus_body(percent_pred_dict_list)

# %%
def characterize_pred_list(prediction_dict_list,
                           prediction_label, 
                           consensus=False):
    correct_id_body = 0
    correct_id = 0
    incorrect = 0
    wrong_body_groupings = []
    for prediction_dict in prediction_dict_list:
        pred_body_set = sorted(list(set(prediction_dict['pred_bodies'])))
        # correct
        if prediction_dict['true_label'] in prediction_dict[prediction_label]:
            if len(pred_body_set) == 1:
                correct_id_body += 1
            else:
                correct_id += 1
                if consensus:
                    wrong_body_groupings.append((prediction_dict['consensus_body'], prediction_dict))
                else:
                    wrong_body_groupings.append((pred_body_set, prediction_dict))
        # incorrect
        else:
            incorrect += 1
    
    wrong_body_set = []
    tracker = []
    for group in wrong_body_groupings:
        test_group = sorted(group[0])
        if test_group not in tracker:
            tracker.append(test_group)
            wrong_body_set.append(group)
    
    total = (correct_id_body + correct_id + incorrect)
    assert total==len(prediction_dict_list), 'total is wrong'
    print('percent correct: {}'.format(correct_id_body/total))
    print('percent correct with wrong body in results: {}'.format(correct_id/total))
    print('percent incorrect: {}'.format(incorrect/total))
    print('number of wrong body groupings: {}' .format(len(wrong_body_set)))
    
    return wrong_body_set, tracker

# %%
percent_wrong_body, percent_tracker =\
characterize_pred_list(percent_pred_dict_list, 'pred_labels')
# Out:
# percent correct: 0.5897858319604613
# percent correct with wrong body in results: 0.36614497528830314
# percent incorrect: 0.04406919275123559
# number of wrong body groupings: 146

# %%
percent_wrong_body, percent_tracker =\
characterize_pred_list(consensus_percent, 'consensus_labels', consensus=True)
# Out:
# percent correct: 0.5897858319604613
# percent correct with wrong body in results: 0.3385502471169687
# percent incorrect: 0.07166392092257001
# number of wrong body groupings: 30

# %%
percent_wrong_body
# Out:
# [(['COUPE', 'SEDAN'],
#   {'consensus_body': ['COUPE', 'SEDAN'],
#    'consensus_labels': ['Acura-Integra_Type_R-2001',
#     'Chevrolet-Cobalt_SS-2010',
#     'BMW-M3_Coupe-2012',
#     'Plymouth-Neon_Coupe-1999',
#     'Suzuki-SX4_Sedan-2012',
#     'Suzuki-Aerio_Sedan-2007'],
#    'pred_bodies': ['CONVERTIBLE',
#     'COUPE',
#     'COUPE',
#     'COUPE',
#     'HATCHBACK',
#     'COUPE',
#     'SEDAN',
#     'SEDAN'],
#    'pred_labels': ['FIAT-500_Convertible-2012',
#     'Acura-Integra_Type_R-2001',
#     'Chevrolet-Cobalt_SS-2010',
#     'BMW-M3_Coupe-2012',
#     'Hyundai-Elantra_Touring_Hatchback-2012',
#     'Plymouth-Neon_Coupe-1999',
#     'Suzuki-SX4_Sedan-2012',
#     'Suzuki-Aerio_Sedan-2007'],
#    'true_body': 'COUPE',
#    'true_label': 'Acura-Integra_Type_R-2001'}),
#  (['SUV', 'VAN'],
#   {'consensus_body': ['SUV', 'VAN'],
#    'consensus_labels': ['Nissan-NV_Passenger_Van-2012',
#     'BMW-X3_SUV-2012',
#     'Jeep-Liberty_SUV-2012',
#     'Ford-Expedition_EL_SUV-2009',
#     'Jeep-Grand_Cherokee_SUV-2012',
#     'Toyota-4Runner_SUV-2012',
#     'Chrysler-Aspen_SUV-2009'],
#    'pred_bodies': ['VAN', 'SUV', 'SUV', 'SUV', 'SUV', 'SUV', 'SUV'],
#    'pred_labels': ['Nissan-NV_Passenger_Van-2012',
#     'BMW-X3_SUV-2012',
#     'Jeep-Liberty_SUV-2012',
#     'Ford-Expedition_EL_SUV-2009',
#     'Jeep-Grand_Cherokee_SUV-2012',
#     'Toyota-4Runner_SUV-2012',
#     'Chrysler-Aspen_SUV-2009'],
#    'true_body': 'VAN',
#    'true_label': 'Nissan-NV_Passenger_Van-2012'}),
#  (['SUV', 'MINIVAN'],
#   {'consensus_body': ['SUV', 'MINIVAN'],
#    'consensus_labels': ['Ford-Freestar_Minivan-2007',
#     'Volvo-XC90_SUV-2007',
#     'Buick-Rainier_SUV-2007'],
#    'pred_bodies': ['MINIVAN', 'SUV', 'SUV'],
#    'pred_labels': ['Ford-Freestar_Minivan-2007',
#     'Volvo-XC90_SUV-2007',
#     'Buick-Rainier_SUV-2007'],
#    'true_body': 'MINIVAN',
#    'true_label': 'Ford-Freestar_Minivan-2007'}),
#  (['SUV', 'HATCHBACK'],
#   {'consensus_body': ['SUV', 'HATCHBACK'],
#    'consensus_labels': ['Nissan-Leaf_Hatchback-2012',
#     'Chevrolet-Traverse_SUV-2012',
#     'Nissan-Juke_Hatchback-2012',
#     'GMC-Acadia_SUV-2012',
#     'Chrysler-Aspen_SUV-2009'],
#    'pred_bodies': ['HATCHBACK',
#     'SUV',
#     'HATCHBACK',
#     'CONVERTIBLE',
#     'COUPE',
#     'SUV',
#     'SEDAN',
#     'SUV'],
#    'pred_labels': ['Nissan-Leaf_Hatchback-2012',
#     'Chevrolet-Traverse_SUV-2012',
#     'Nissan-Juke_Hatchback-2012',
#     'Chrysler-PT_Cruiser_Convertible-2008',
#     'Bentley-Continental_GT_Coupe-2007',
#     'GMC-Acadia_SUV-2012',
#     'Chevrolet-Sonic_Sedan-2012',
#     'Chrysler-Aspen_SUV-2009'],
#    'true_body': 'HATCHBACK',
#    'true_label': 'Nissan-Leaf_Hatchback-2012'}),
#  (['VAN', 'COUPE'],
#   {'consensus_body': ['VAN', 'COUPE'],
#    'consensus_labels': ['Chevrolet-Express_Cargo_Van-2007',
#     'Acura-Integra_Type_R-2001',
#     'Plymouth-Neon_Coupe-1999',
#     'Chevrolet-Express_Van-2007'],
#    'pred_bodies': ['VAN', 'COUPE', 'COUPE', 'VAN'],
#    'pred_labels': ['Chevrolet-Express_Cargo_Van-2007',
#     'Acura-Integra_Type_R-2001',
#     'Plymouth-Neon_Coupe-1999',
#     'Chevrolet-Express_Van-2007'],
#    'true_body': 'VAN',
#    'true_label': 'Chevrolet-Express_Cargo_Van-2007'}),
#  (['SEDAN', 'HATCHBACK'],
#   {'consensus_body': ['SEDAN', 'HATCHBACK'],
#    'consensus_labels': ['Chevrolet-Sonic_Sedan-2012',
#     'Volkswagen-Beetle_Hatchback-2012',
#     'Suzuki-Aerio_Sedan-2007',
#     'Ford-Fiesta_Sedan-2012',
#     'Hyundai-Elantra_Sedan-2007',
#     'Hyundai-Elantra_Touring_Hatchback-2012'],
#    'pred_bodies': ['SEDAN',
#     'HATCHBACK',
#     'SEDAN',
#     'SEDAN',
#     'WAGON',
#     'WAGON',
#     'SEDAN',
#     'HATCHBACK'],
#    'pred_labels': ['Chevrolet-Sonic_Sedan-2012',
#     'Volkswagen-Beetle_Hatchback-2012',
#     'Suzuki-Aerio_Sedan-2007',
#     'Ford-Fiesta_Sedan-2012',
#     'Dodge-Caliber_Wagon-2012',
#     'Dodge-Caliber_Wagon-2007',
#     'Hyundai-Elantra_Sedan-2007',
#     'Hyundai-Elantra_Touring_Hatchback-2012'],
#    'true_body': 'SEDAN',
#    'true_label': 'Chevrolet-Sonic_Sedan-2012'}),
#  (['WAGON', 'SEDAN'],
#   {'consensus_body': ['WAGON', 'SEDAN'],
#    'consensus_labels': ['Audi-100_Wagon-1994', 'Audi-100_Sedan-1994'],
#    'pred_bodies': ['WAGON', 'SEDAN'],
#    'pred_labels': ['Audi-100_Wagon-1994', 'Audi-100_Sedan-1994'],
#    'true_body': 'WAGON',
#    'true_label': 'Audi-100_Wagon-1994'}),
#  (['COUPE', 'HATCHBACK'],
#   {'consensus_body': ['COUPE', 'HATCHBACK'],
#    'consensus_labels': ['Nissan-Leaf_Hatchback-2012',
#     'Acura-Integra_Type_R-2001',
#     'Bentley-Continental_GT_Coupe-2007'],
#    'pred_bodies': ['HATCHBACK', 'SEDAN', 'COUPE', 'COUPE'],
#    'pred_labels': ['Nissan-Leaf_Hatchback-2012',
#     'Porsche-Panamera_Sedan-2012',
#     'Acura-Integra_Type_R-2001',
#     'Bentley-Continental_GT_Coupe-2007'],
#    'true_body': 'HATCHBACK',
#    'true_label': 'Nissan-Leaf_Hatchback-2012'}),
#  (['CONVERTIBLE', 'COUPE'],
#   {'consensus_body': ['CONVERTIBLE', 'COUPE'],
#    'consensus_labels': ['Audi-S5_Convertible-2012', 'Audi-S5_Coupe-2012'],
#    'pred_bodies': ['CONVERTIBLE', 'COUPE'],
#    'pred_labels': ['Audi-S5_Convertible-2012', 'Audi-S5_Coupe-2012'],
#    'true_body': 'CONVERTIBLE',
#    'true_label': 'Audi-S5_Convertible-2012'}),
#  (['SEDAN', 'SUV'],
#   {'consensus_body': ['SEDAN', 'SUV'],
#    'consensus_labels': ['Buick-Verano_Sedan-2012',
#     'Buick-Regal_GS-2012',
#     'Buick-Enclave_SUV-2012'],
#    'pred_bodies': ['SEDAN', 'SEDAN', 'SUV'],
#    'pred_labels': ['Buick-Verano_Sedan-2012',
#     'Buick-Regal_GS-2012',
#     'Buick-Enclave_SUV-2012'],
#    'true_body': 'SEDAN',
#    'true_label': 'Buick-Verano_Sedan-2012'}),
#  (['SEDAN', 'CONVERTIBLE'],
#   {'consensus_body': ['SEDAN', 'CONVERTIBLE'],
#    'consensus_labels': ['Audi-V8_Sedan-1994',
#     'Audi-100_Sedan-1994',
#     'Mercedes_Benz-300_Class_Convertible-1993'],
#    'pred_bodies': ['SEDAN', 'SEDAN', 'CONVERTIBLE'],
#    'pred_labels': ['Audi-V8_Sedan-1994',
#     'Audi-100_Sedan-1994',
#     'Mercedes_Benz-300_Class_Convertible-1993'],
#    'true_body': 'SEDAN',
#    'true_label': 'Audi-V8_Sedan-1994'}),
#  (['SUV', 'PICKUP'],
#   {'consensus_body': ['SUV', 'PICKUP'],
#    'consensus_labels': ['AM-General_Hummer_SUV-2000',
#     'Jeep-Wrangler_SUV-2012',
#     'HUMMER-H3T_Crew_Cab-2010',
#     'HUMMER-H2_SUT_Crew_Cab-2009',
#     'Jeep-Liberty_SUV-2012'],
#    'pred_bodies': ['SUV', 'SUV', 'PICKUP', 'PICKUP', 'SUV'],
#    'pred_labels': ['AM-General_Hummer_SUV-2000',
#     'Jeep-Wrangler_SUV-2012',
#     'HUMMER-H3T_Crew_Cab-2010',
#     'HUMMER-H2_SUT_Crew_Cab-2009',
#     'Jeep-Liberty_SUV-2012'],
#    'true_body': 'SUV',
#    'true_label': 'AM-General_Hummer_SUV-2000'}),
#  (['HATCHBACK', 'WAGON'],
#   {'consensus_body': ['HATCHBACK', 'WAGON'],
#    'consensus_labels': ['Volkswagen-Beetle_Hatchback-2012',
#     'Volvo-C30_Hatchback-2012',
#     'Hyundai-Veloster_Hatchback-2012',
#     'Dodge-Caliber_Wagon-2007'],
#    'pred_bodies': ['HATCHBACK',
#     'HATCHBACK',
#     'HATCHBACK',
#     'WAGON',
#     'COUPE',
#     'SUV'],
#    'pred_labels': ['Volkswagen-Beetle_Hatchback-2012',
#     'Volvo-C30_Hatchback-2012',
#     'Hyundai-Veloster_Hatchback-2012',
#     'Dodge-Caliber_Wagon-2007',
#     'Lamborghini-Gallardo_LP_570_4_Superleggera-2012',
#     'Dodge-Journey_SUV-2012'],
#    'true_body': 'HATCHBACK',
#    'true_label': 'Hyundai-Veloster_Hatchback-2012'}),
#  (['WAGON', 'SUV'],
#   {'consensus_body': ['WAGON', 'SUV'],
#    'consensus_labels': ['Audi-100_Wagon-1994', 'Volvo-XC90_SUV-2007'],
#    'pred_bodies': ['WAGON', 'SUV', 'SEDAN'],
#    'pred_labels': ['Audi-100_Wagon-1994',
#     'Volvo-XC90_SUV-2007',
#     'Audi-V8_Sedan-1994'],
#    'true_body': 'WAGON',
#    'true_label': 'Audi-100_Wagon-1994'}),
#  (['COUPE', 'WAGON'],
#   {'consensus_body': ['COUPE', 'WAGON'],
#    'consensus_labels': ['BMW-1_Series_Coupe-2012',
#     'BMW-3_Series_Wagon-2012',
#     'BMW-M3_Coupe-2012'],
#    'pred_bodies': ['COUPE', 'WAGON', 'COUPE', 'SUV'],
#    'pred_labels': ['BMW-1_Series_Coupe-2012',
#     'BMW-3_Series_Wagon-2012',
#     'BMW-M3_Coupe-2012',
#     'BMW-X3_SUV-2012'],
#    'true_body': 'COUPE',
#    'true_label': 'BMW-1_Series_Coupe-2012'}),
#  (['COUPE', 'MINIVAN'],
#   {'consensus_body': ['COUPE', 'MINIVAN'],
#    'consensus_labels': ['Dodge-Caravan_Minivan-1997',
#     'Chevrolet-Monte_Carlo_Coupe-2007',
#     'Nissan-240SX_Coupe-1998'],
#    'pred_bodies': ['MINIVAN', 'COUPE', 'VAN', 'COUPE', 'SEDAN'],
#    'pred_labels': ['Dodge-Caravan_Minivan-1997',
#     'Chevrolet-Monte_Carlo_Coupe-2007',
#     'Dodge-Sprinter_Cargo_Van-2009',
#     'Nissan-240SX_Coupe-1998',
#     'Ford-Focus_Sedan-2007'],
#    'true_body': 'MINIVAN',
#    'true_label': 'Dodge-Caravan_Minivan-1997'}),
#  (['SEDAN', 'PICKUP'],
#   {'consensus_body': ['SEDAN', 'PICKUP'],
#    'consensus_labels': ['Rolls_Royce-Phantom_Sedan-2012',
#     'Bentley-Arnage_Sedan-2009',
#     'Bentley-Mulsanne_Sedan-2011',
#     'Ford-F_450_Super_Duty_Crew_Cab-2012',
#     'Ford-Ranger_SuperCab-2011',
#     'Cadillac-CTS_V_Sedan-2012',
#     'Chevrolet-Sonic_Sedan-2012',
#     'Rolls_Royce-Ghost_Sedan-2012'],
#    'pred_bodies': ['SEDAN',
#     'VAN',
#     'SEDAN',
#     'COUPE',
#     'CONVERTIBLE',
#     'SEDAN',
#     'SUV',
#     'PICKUP',
#     'PICKUP',
#     'SEDAN',
#     'SEDAN',
#     'SEDAN'],
#    'pred_labels': ['Rolls_Royce-Phantom_Sedan-2012',
#     'Nissan-NV_Passenger_Van-2012',
#     'Bentley-Arnage_Sedan-2009',
#     'Audi-S5_Coupe-2012',
#     'Audi-S5_Convertible-2012',
#     'Bentley-Mulsanne_Sedan-2011',
#     'Toyota-4Runner_SUV-2012',
#     'Ford-F_450_Super_Duty_Crew_Cab-2012',
#     'Ford-Ranger_SuperCab-2011',
#     'Cadillac-CTS_V_Sedan-2012',
#     'Chevrolet-Sonic_Sedan-2012',
#     'Rolls_Royce-Ghost_Sedan-2012'],
#    'true_body': 'SEDAN',
#    'true_label': 'Bentley-Arnage_Sedan-2009'}),
#  (['SEDAN', 'MINIVAN'],
#   {'consensus_body': ['SEDAN', 'MINIVAN'],
#    'consensus_labels': ['Acura-TL_Type_S-2008', 'Honda-Odyssey_Minivan-2007'],
#    'pred_bodies': ['SEDAN', 'MINIVAN', 'HATCHBACK'],
#    'pred_labels': ['Acura-TL_Type_S-2008',
#     'Honda-Odyssey_Minivan-2007',
#     'Hyundai-Elantra_Touring_Hatchback-2012'],
#    'true_body': 'MINIVAN',
#    'true_label': 'Honda-Odyssey_Minivan-2007'}),
#  (['CONVERTIBLE', 'MINIVAN'],
#   {'consensus_body': ['CONVERTIBLE', 'MINIVAN'],
#    'consensus_labels': ['Chrysler-Sebring_Convertible-2010',
#     'Chrysler-Town_and_Country_Minivan-2012'],
#    'pred_bodies': ['CONVERTIBLE', 'MINIVAN'],
#    'pred_labels': ['Chrysler-Sebring_Convertible-2010',
#     'Chrysler-Town_and_Country_Minivan-2012'],
#    'true_body': 'CONVERTIBLE',
#    'true_label': 'Chrysler-Sebring_Convertible-2010'}),
#  (['HATCHBACK', 'CONVERTIBLE'],
#   {'consensus_body': ['HATCHBACK', 'CONVERTIBLE'],
#    'consensus_labels': ['Volkswagen-Beetle_Hatchback-2012',
#     'FIAT-500_Convertible-2012'],
#    'pred_bodies': ['HATCHBACK', 'CONVERTIBLE'],
#    'pred_labels': ['Volkswagen-Beetle_Hatchback-2012',
#     'FIAT-500_Convertible-2012'],
#    'true_body': 'CONVERTIBLE',
#    'true_label': 'FIAT-500_Convertible-2012'}),
#  (['SUV', 'COUPE'],
#   {'consensus_body': ['SUV', 'COUPE'],
#    'consensus_labels': ['GMC-Terrain_SUV-2012',
#     'Cadillac-SRX_SUV-2012',
#     'GMC-Yukon_Hybrid_SUV-2012',
#     'Audi-A5_Coupe-2012',
#     'GMC-Acadia_SUV-2012',
#     'Toyota-Sequoia_SUV-2012',
#     'Dodge-Journey_SUV-2012',
#     'Jeep-Grand_Cherokee_SUV-2012',
#     'Chevrolet-Traverse_SUV-2012',
#     'BMW-X6_SUV-2012',
#     'Buick-Rainier_SUV-2007',
#     'BMW-X3_SUV-2012',
#     'Chevrolet-Tahoe_Hybrid_SUV-2012',
#     'Bentley-Continental_GT_Coupe-2007',
#     'Jeep-Compass_SUV-2012',
#     'Audi-S5_Coupe-2012',
#     'Ford-Edge_SUV-2012'],
#    'pred_bodies': ['SUV',
#     'SEDAN',
#     'SUV',
#     'SUV',
#     'COUPE',
#     'SUV',
#     'PICKUP',
#     'SUV',
#     'SUV',
#     'SUV',
#     'SUV',
#     'SUV',
#     'HATCHBACK',
#     'SUV',
#     'SUV',
#     'HATCHBACK',
#     'PICKUP',
#     'SUV',
#     'COUPE',
#     'WAGON',
#     'SUV',
#     'COUPE',
#     'HATCHBACK',
#     'SUV'],
#    'pred_labels': ['GMC-Terrain_SUV-2012',
#     'Chevrolet-Sonic_Sedan-2012',
#     'Cadillac-SRX_SUV-2012',
#     'GMC-Yukon_Hybrid_SUV-2012',
#     'Audi-A5_Coupe-2012',
#     'GMC-Acadia_SUV-2012',
#     'Chevrolet-Avalanche_Crew_Cab-2012',
#     'Toyota-Sequoia_SUV-2012',
#     'Dodge-Journey_SUV-2012',
#     'Jeep-Grand_Cherokee_SUV-2012',
#     'Chevrolet-Traverse_SUV-2012',
#     'BMW-X6_SUV-2012',
#     'Scion-xD_Hatchback-2012',
#     'Buick-Rainier_SUV-2007',
#     'BMW-X3_SUV-2012',
#     'Nissan-Leaf_Hatchback-2012',
#     'GMC-Canyon_Extended_Cab-2012',
#     'Chevrolet-Tahoe_Hybrid_SUV-2012',
#     'Bentley-Continental_GT_Coupe-2007',
#     'Dodge-Caliber_Wagon-2012',
#     'Jeep-Compass_SUV-2012',
#     'Audi-S5_Coupe-2012',
#     'Acura-ZDX_Hatchback-2012',
#     'Ford-Edge_SUV-2012'],
#    'true_body': 'SUV',
#    'true_label': 'GMC-Terrain_SUV-2012'}),
#  (['MINIVAN', 'HATCHBACK'],
#   {'consensus_body': ['MINIVAN', 'HATCHBACK'],
#    'consensus_labels': ['Honda-Odyssey_Minivan-2007',
#     'Scion-xD_Hatchback-2012'],
#    'pred_bodies': ['MINIVAN', 'HATCHBACK', 'SEDAN'],
#    'pred_labels': ['Honda-Odyssey_Minivan-2007',
#     'Scion-xD_Hatchback-2012',
#     'Acura-RL_Sedan-2012'],
#    'true_body': 'MINIVAN',
#    'true_label': 'Honda-Odyssey_Minivan-2007'}),
#  (['MINIVAN', 'WAGON'],
#   {'consensus_body': ['MINIVAN', 'WAGON'],
#    'consensus_labels': ['Chrysler-Town_and_Country_Minivan-2012',
#     'Dodge-Magnum_Wagon-2008'],
#    'pred_bodies': ['MINIVAN', 'WAGON', 'SEDAN', 'SUV'],
#    'pred_labels': ['Chrysler-Town_and_Country_Minivan-2012',
#     'Dodge-Magnum_Wagon-2008',
#     'Suzuki-Aerio_Sedan-2007',
#     'Ford-Expedition_EL_SUV-2009'],
#    'true_body': 'MINIVAN',
#    'true_label': 'Chrysler-Town_and_Country_Minivan-2012'}),
#  (['MINIVAN', 'VAN'],
#   {'consensus_body': ['MINIVAN', 'VAN'],
#    'consensus_labels': ['Mercedes_Benz-Sprinter_Van-2012',
#     'Honda-Odyssey_Minivan-2007',
#     'Dodge-Ram_C_V_Cargo_Van_Minivan-2012',
#     'Dodge-Sprinter_Cargo_Van-2009',
#     'Chrysler-Town_and_Country_Minivan-2012',
#     'Ford-Freestar_Minivan-2007',
#     'Dodge-Caravan_Minivan-1997',
#     'Chevrolet-Express_Van-2007'],
#    'pred_bodies': ['VAN',
#     'MINIVAN',
#     'MINIVAN',
#     'VAN',
#     'MINIVAN',
#     'SUV',
#     'HATCHBACK',
#     'SUV',
#     'MINIVAN',
#     'WAGON',
#     'MINIVAN',
#     'VAN'],
#    'pred_labels': ['Mercedes_Benz-Sprinter_Van-2012',
#     'Honda-Odyssey_Minivan-2007',
#     'Dodge-Ram_C_V_Cargo_Van_Minivan-2012',
#     'Dodge-Sprinter_Cargo_Van-2009',
#     'Chrysler-Town_and_Country_Minivan-2012',
#     'Buick-Rainier_SUV-2007',
#     'Volkswagen-Golf_Hatchback-1991',
#     'Land_Rover-Rover_Range_Rover_SUV-2012',
#     'Ford-Freestar_Minivan-2007',
#     'Daewoo-Nubira_Wagon-2002',
#     'Dodge-Caravan_Minivan-1997',
#     'Chevrolet-Express_Van-2007'],
#    'true_body': 'MINIVAN',
#    'true_label': 'Chrysler-Town_and_Country_Minivan-2012'}),
#  (['VAN', 'PICKUP'],
#   {'consensus_body': ['VAN', 'PICKUP'],
#    'consensus_labels': ['Ford-E_Series_Wagon_Van-2012',
#     'Dodge-Ram_Pickup_3500_Crew_Cab-2010'],
#    'pred_bodies': ['VAN', 'PICKUP'],
#    'pred_labels': ['Ford-E_Series_Wagon_Van-2012',
#     'Dodge-Ram_Pickup_3500_Crew_Cab-2010'],
#    'true_body': 'VAN',
#    'true_label': 'Ford-E_Series_Wagon_Van-2012'}),
#  (['CONVERTIBLE', 'SUV'],
#   {'consensus_body': ['CONVERTIBLE', 'SUV'],
#    'consensus_labels': ['Chrysler-Sebring_Convertible-2010',
#     'Ford-Mustang_Convertible-2007',
#     'Chrysler-PT_Cruiser_Convertible-2008',
#     'Mercedes_Benz-300_Class_Convertible-1993',
#     'Buick-Rainier_SUV-2007'],
#    'pred_bodies': ['CONVERTIBLE',
#     'CONVERTIBLE',
#     'CONVERTIBLE',
#     'CONVERTIBLE',
#     'SUV',
#     'COUPE'],
#    'pred_labels': ['Chrysler-Sebring_Convertible-2010',
#     'Ford-Mustang_Convertible-2007',
#     'Chrysler-PT_Cruiser_Convertible-2008',
#     'Mercedes_Benz-300_Class_Convertible-1993',
#     'Buick-Rainier_SUV-2007',
#     'Plymouth-Neon_Coupe-1999'],
#    'true_body': 'CONVERTIBLE',
#    'true_label': 'Chrysler-Sebring_Convertible-2010'}),
#  (['CONVERTIBLE', 'PICKUP'],
#   {'consensus_body': ['CONVERTIBLE', 'PICKUP'],
#    'consensus_labels': ['Geo-Metro_Convertible-1993',
#     'Chevrolet-Corvette_Convertible-2012',
#     'Mercedes_Benz-300_Class_Convertible-1993',
#     'Ford-Mustang_Convertible-2007',
#     'Chevrolet-Camaro_Convertible-2012',
#     'Dodge-Dakota_Crew_Cab-2010'],
#    'pred_bodies': ['CONVERTIBLE',
#     'CONVERTIBLE',
#     'CONVERTIBLE',
#     'CONVERTIBLE',
#     'CONVERTIBLE',
#     'PICKUP'],
#    'pred_labels': ['Geo-Metro_Convertible-1993',
#     'Chevrolet-Corvette_Convertible-2012',
#     'Mercedes_Benz-300_Class_Convertible-1993',
#     'Ford-Mustang_Convertible-2007',
#     'Chevrolet-Camaro_Convertible-2012',
#     'Dodge-Dakota_Crew_Cab-2010'],
#    'true_body': 'CONVERTIBLE',
#    'true_label': 'Chevrolet-Corvette_Convertible-2012'}),
#  (['CONVERTIBLE', 'WAGON'],
#   {'consensus_body': ['CONVERTIBLE', 'WAGON'],
#    'consensus_labels': ['BMW-6_Series_Convertible-2007',
#     'Mercedes_Benz-300_Class_Convertible-1993',
#     'Aston_Martin-Martin_V8_Vantage_Convertible-2012',
#     'BMW-3_Series_Wagon-2012',
#     'Audi-RS_4_Convertible-2008',
#     'BMW-M6_Convertible-2010',
#     'Chevrolet-Camaro_Convertible-2012',
#     'Audi-S5_Convertible-2012',
#     'Aston_Martin-Martin_Virage_Convertible-2012',
#     'Ford-Mustang_Convertible-2007',
#     'Chrysler-Crossfire_Convertible-2008',
#     'Daewoo-Nubira_Wagon-2002'],
#    'pred_bodies': ['CONVERTIBLE',
#     'CONVERTIBLE',
#     'COUPE',
#     'CONVERTIBLE',
#     'WAGON',
#     'CONVERTIBLE',
#     'CONVERTIBLE',
#     'CONVERTIBLE',
#     'CONVERTIBLE',
#     'CONVERTIBLE',
#     'CONVERTIBLE',
#     'CONVERTIBLE',
#     'WAGON'],
#    'pred_labels': ['BMW-6_Series_Convertible-2007',
#     'Mercedes_Benz-300_Class_Convertible-1993',
#     'Nissan-240SX_Coupe-1998',
#     'Aston_Martin-Martin_V8_Vantage_Convertible-2012',
#     'BMW-3_Series_Wagon-2012',
#     'Audi-RS_4_Convertible-2008',
#     'BMW-M6_Convertible-2010',
#     'Chevrolet-Camaro_Convertible-2012',
#     'Audi-S5_Convertible-2012',
#     'Aston_Martin-Martin_Virage_Convertible-2012',
#     'Ford-Mustang_Convertible-2007',
#     'Chrysler-Crossfire_Convertible-2008',
#     'Daewoo-Nubira_Wagon-2002'],
#    'true_body': 'CONVERTIBLE',
#    'true_label': 'BMW-M6_Convertible-2010'}),
#  (['VAN', 'HATCHBACK'],
#   {'consensus_body': ['VAN', 'HATCHBACK'],
#    'consensus_labels': ['GMC-Savana_Van-2012',
#     'Chevrolet-Express_Van-2007',
#     'Volkswagen-Golf_Hatchback-1991',
#     'Chevrolet-Express_Cargo_Van-2007'],
#    'pred_bodies': ['VAN', 'VAN', 'HATCHBACK', 'VAN'],
#    'pred_labels': ['GMC-Savana_Van-2012',
#     'Chevrolet-Express_Van-2007',
#     'Volkswagen-Golf_Hatchback-1991',
#     'Chevrolet-Express_Cargo_Van-2007'],
#    'true_body': 'VAN',
#    'true_label': 'Chevrolet-Express_Van-2007'}),
#  (['PICKUP', 'COUPE'],
#   {'consensus_body': ['PICKUP', 'COUPE'],
#    'consensus_labels': ['Chevrolet-Avalanche_Crew_Cab-2012',
#     'Chevrolet-Monte_Carlo_Coupe-2007'],
#    'pred_bodies': ['PICKUP', 'COUPE', 'SEDAN'],
#    'pred_labels': ['Chevrolet-Avalanche_Crew_Cab-2012',
#     'Chevrolet-Monte_Carlo_Coupe-2007',
#     'Dodge-Charger_SRT_8-2009'],
#    'true_body': 'COUPE',
#    'true_label': 'Chevrolet-Monte_Carlo_Coupe-2007'})]

# %%
top_5_wrong_body, top_5_tracker =\
characterize_pred_list(top_5_pred_dict_list, 'pred_labels')
# Out:
# percent correct: 0.15815485996705106
# percent correct with wrong body in results: 0.7895387149917628
# percent incorrect: 0.05230642504118616
# number of wrong body groupings: 152

# %%
top_5_wrong_body, top_5_tracker =\
characterize_pred_list(consensus_top_5, 'consensus_labels')
# Out:
# percent correct: 0.15815485996705106
# percent correct with wrong body in results: 0.765650741350906
# percent incorrect: 0.07619439868204284
# number of wrong body groupings: 152
